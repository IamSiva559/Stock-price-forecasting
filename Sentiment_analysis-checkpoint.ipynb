# %%
import tweepy
from preprocessor.api import clean
import re
from textblob import TextBlob
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

#Constants

CONSUMER_KEY= 'nlxa0UiERGBRU3xdnYDki0zXF'
CUSTOMER_SECRET= 'mRCTBVRZyZvFDZVlHypZQe5O6tZZpCeseRCIxbEska685sqoI4'

ACCESS_TOKEN='759618066-EPW2DXdStQO8Y5kxm87nZ8w1YRyG5XsyJOnNXLKd'
ACCESS_TOKEN_TOKEN='NUCBdTuERoFzf2vqgXEltBtqWRgNeIGGYpjbCb8Ztn4ee'

NUM_OF_TWEETS = int(300)

# %%
def get_stock_sentiment(stock_symbol):
    symbol = stock_symbol.split(".")[0].lower() + " stock"
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CUSTOMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_TOKEN)
    user = tweepy.API(auth)
    tweets = tweepy.Cursor(user.search, q=str(symbol), tweet_mode='extended', lang='en',exclude_replies=True).items(NUM_OF_TWEETS)
    tweet_list = [] #List of tweets alongside polarity
    global_polarity = 0 #Polarity of all tweets === Sum of polarities of individual tweets
    tw_list=[] #List of tweets only => to be displayed on web page
    #Count Positive, Negative to plot pie chart
    pos=0 #Num of pos tweets
    neg=1 #Num of negative tweets
    for tweet in tweets:
        count=20 #Num of tweets to be displayed on web page
        #Convert to Textblob format for assigning polarity
        tw2 = tweet.full_text
        tw = tweet.full_text
        #Clean
        tw=clean(tw)
        #print("-------------------------------CLEANED TWEET-----------------------------")
        #print(tw)
        #Replace &amp; by &
        tw=re.sub('&amp;','&',tw)
        #Remove :
        tw=re.sub(':','',tw)
        #print("-------------------------------TWEET AFTER REGEX MATCHING-----------------------------")
        #print(tw)
        #Remove Emojis and Hindi Characters
        tw=tw.encode('ascii', 'ignore').decode('ascii')

        #print("-------------------------------TWEET AFTER REMOVING NON ASCII CHARS-----------------------------")
        #print(tw)
        blob = TextBlob(tw)
        polarity = 0 #Polarity of single individual tweet
        for sentence in blob.sentences:
            polarity += sentence.sentiment.polarity
            if polarity>0:
                pos=pos+1
            if polarity<0:
                neg=neg+1

            global_polarity += sentence.sentiment.polarity
        if count > 0:
            tw_list.append(tw2)

        #tweet_list.append(Tweet(tw, polarity))
        count=count-1
    try:
        global_polarity = global_polarity / len(tw_list)
    except:
        pass

    neutral=NUM_OF_TWEETS-pos-neg
    if neutral<0:
        neg=neg+neutral
        neutral=20
    labels=['Positive','Negative','Neutral']
    sizes = [pos,neg,neutral]
    explode = (0, 0, 0)
    fig = plt.figure(figsize=(7.2,4.8),dpi=65)
    fig1, ax1 = plt.subplots(figsize=(7.2,4.8),dpi=65)
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
    # Equal aspect ratio ensures that pie is drawn as a circle
    ax1.axis('equal')  
    plt.tight_layout()
    plt.savefig("sa.png")
    plt.close(fig)
    #plt.show()
    if pos-neg > 10:
        suggestion = " According to sentiment analysis, stock price may RISE"
        tw_pol = " Overall Positive"
        
    elif neg-pos > 10:
        suggestion = " According to sentiment analysis, stock price may FALL"
        tw_pol = " Overall Negative"

    else:
        suggestion = " According to sentiment analysis, there wont be much volatilty in the stock price"
        tw_pol = " Almost neautral "


    return suggestion, tw_list, tw_pol

# %%
get_stock_sentiment("tatamotors stock")
# Out:
# (' According to sentiment analysis, there wont be much volatilty in the stock price',
#  ['RT @mystockbookapp: #MonthlyAutoSaleswithStockBook\n\nTata Motors - January 2021 - Auto Sales Snapshot\n\nSource : Company Filing on Indian Sto…',
#   'RT @mystockbookapp: #MonthlyAutoSaleswithStockBook\n\nTata Motors - January 2021 - Auto Sales Snapshot\n\nSource : Company Filing on Indian Sto…',
#   '#MonthlyAutoSaleswithStockBook\n\nTata Motors - January 2021 - Auto Sales Snapshot\n\nSource : Company Filing on Indian Stock exchanges\n\n#StockBookApp #Investwise #StockMarket #stockmarkets #stockmarketnews #AutoSales #MonthlyUpdate #Tatamotors https://t.co/upINRj3RN6',
#   'RT @IIFLMarkets: Tata Motors reports strong all-round performance revenue growth at 5.5%; stock gains 3%\nhttps://t.co/WVPhXxSkuJ\n#Tatamotors',
#   'Tata Motors reports strong all-round performance revenue growth at 5.5%; stock gains 3%\nhttps://t.co/WVPhXxSkuJ\n#Tatamotors',
#   '#TATAMOTORS - not good scrapping policy!\n\nSo stock will deep 🔻🔻🔻🔻 #frontpage_app https://t.co/mZ3XLUSMBL',
#   '#TATAMOTORS - not good scrapping policy!\n\nSo stock will deep 🔻🔻🔻🔻 #frontpage_app https://t.co/Af4oZLKibl',
#   'Auto stocks, ICICI Bank, Tata Motors, Tech Mahindra in focus\n\nRead more at: https://t.co/QFj0Sr3uih\n\n#capitalmarket #financialmarket #autostock #icicibank #tatamotors #techmahindra #stockalert #stockmarket #stockmarketindia #stocknews',
#   'Should We Buy Tata Motors Share\n\n #tatamotors\n#tata_motors_stock\n\nhttps://t.co/6mWgmUVwJu',
#   '#Budget2021 stock. \n1.#ITC.\n2.#RVNL \n\nAnd special pick \n3.#Tatamotors\nView for #oneyear to two year.',
#   'RT @ChoiceBroking: India’s largest carmaker posted profit after 3 quarters, and made strong sales in Q3.\nWatch this space for upcoming Quar…',
#   "3 stock's too Down 01/02/2021\nSHARE MARKET 🔥\n(1). RELIANCE\n(2). HDFC BANK\n(3). AXIS BANK\n#markets #stock #Reliance #stocks #nifty50 #StocksToWatch #investing #TataMotors #StocksToBuy #sharemarket #adilafzal https://t.co/I5nFW0ZPYW",
#   'India’s largest carmaker posted profit after 3 quarters, and made strong sales in Q3.\nWatch this space for upcoming Quarter results and stock market updates.\n\n#TATA #TATAMOTORS #Q3FY21 #Q3results #StockMarket #investing https://t.co/5s9PbgmLDE',
#   '@TataMotors is the only Indian auto company to get above 4 Star safety ratings but, are you aware that its stock has also rallied more than 400% since the lockdown started in India?\n\n#TataMotors #BSE #nseindia #Nifty #ValueInvesting #thefinanalyst https://t.co/94mUXdooTy',
#   'RT @CAPratik_INDIAN: #Tatamotors \n\nAnother Decent Set Of Numbers..\n\nStock Is Ready For 345++ in Medium Term',
#   'People were calling Tata motors as “Ghata motors” and predicted it become a penny stock soon.\n\nNow when I try to find their tweets, they seem to have deleted them. \n\nTwo constant conviction on TaMo I have seen from two people were @nishkumar1977 &amp; @kuttrapali \n\n#Tatamotors #nifty',
#   '#Tatamotors \n\nAnother Decent Set Of Numbers..\n\nStock Is Ready For 345++ in Medium Term https://t.co/RGzirnPptn',
#   'Subscribe to ValueMulticaps #Stock #subscription  will do well but Which Stock in #AutoSector is Extremely important in the overall \n\nVisit- https://t.co/jWVjVWC3wI\nTelegram- https://t.co/drUlQByiyj\n\n#Valuemulticaps  #StockMarket #nifty50  #TataMotors #eichermotors  #BajajAuto https://t.co/At77tBJi0P',
#   '#gotostockupdate #ftbs #leadingscorers : Find The Best Stock Contest. Leading scorers after half way through... TATAMOTORS all the way... ✅ https://t.co/gephR1ZQPv',
#   'Did anyone bought Tata motor stock on its Intrinsic price - around Rs.65-75 ? The opportunity was during lockdown . #TataMotors #StockMarket https://t.co/AFBP0RCHJf',
#   'Tata Motors Latest News | #TataMotors Share News | Tata Motors Stock Update | #RatanTata Stock\nCheck: https://t.co/LqBgGhbZRo',
#   '@TataMotors ’s 44% surge this month is easily the top performance among shares on India’s NSE Nifty 50 Index.\n\nhttps://t.co/zaFJmniD9H\n\n@htTweets',
#   "#Turnover on the #NSE's futures &amp; #options (F&amp;O) segment was Rs 17.93 lakh crore compared with Rs 77.23 lakh crore in the previous #session.\n\n#TataMotors, #TataSteel and #RIL were the top traded stock #futures contracts in F&amp;O segment for #Februaryexpiry.",
#   'Today our stock future intraday call profit Rs 28905 in that icicibank hit 2nd target book profit Rs 20625 tatamotors stop loss 0.60 paisa loss 3420 and cipla book 828 at 3:20 pm profit Rs11700 see below image join call us 09328994865 \nJoin today and get budget apportunity call https://t.co/kXWkE6m8EQ',
#   'Stock for feb month \n\nBuy buy buy\n\nIcici bank -cmp - 529 #icicibank \nBritannia - cmp - 3603 - #Britannia \nTata motors - cmp - 267 - #Tatamotors \nTata power - cmp - 77 -#tatapower \n\n#boombaam #bullseyetrades',
#   '@mukund https://t.co/0D0Xh4PzbN  (and there were rumors they might partner w/TSLA -- prob. want accts for some of that stock move.',
#   "Final Update &amp; THREAD Closed #TATAMOTORS\n\n- Attached Hourly + Daily Price Chart\n- Downside Target of 260 met today (Low=259), 10 DEMA retest done🥳💯\n- Could slip further also but not my problem now👍\n\nNote: This is the 4th time I've covered this stock this month!🤣See my THREADs https://t.co/8vdU1E1MMR",
#   'Tata Motors Ltd. - ADR to report earnings on May 30, 2021. Earnings per share (EPS) estimate: $0.27 $TTM #TataMotors #stockmarket #stock #earnings #money #trading #investing #daytrading #news #today https://t.co/G7xc1f4Qul',
#   '#Tatamotors \n\nLooking good both for trading and investment.\n\n#stocks #Nifty #StockMarket #trading #Investment #TradingView \n#sst\n#money #nse #bse #stock #ipo',
#   '#tatamotors stock above 275 can touch 285-290 with in 3-4 trading days view negate below 265. cmp 271.5',
#   '@deepaliranaa @TataMotors_Cars @CNBC_Awaaz You are so lucky cover all stock mkt &amp; all new launching car',
#   "#Gks_teja's Watchlist \nKing 👑 of the today's stocks \n#TataMotors \nOpening it's self gap-down.\nIn first 15 min only it's gave 3% return.\n\nIf any one traded in this stock please let me know in common section I am very happy to read it 😃",
#   "@mohit_maxmoh @tiara_mishra Hey!! @mohit_maxmoh check this I hope it will find you easy! Today's most traded #Futures &amp; #options  #reliance #ICICIBank #Index call &amp; put options #nifty #banknifty #stock call &amp; put options #SBIN #Tatamotors link to: https://t.co/z5lHIF0Tqi https://t.co/hjnqJguo8O",
#   "Return my Money !! I don't want to use this defected car @Maruti_Corp\nI don't want use #death goods\nHR 07 AC 7628 #wagon r (2021) #CNG\nNo one Should buy it \n#Defective  stock\n@ConsumerReports @Automotive_News\n\n@Automotive_News\n@autox @ndtv @sudhirchaudhary @TataMotors @METI_JPN https://t.co/mToUHDl7gu",
#   '#TataMotors shares gain 52% in January so far; analysts think it remains a long-term bet\n\nGlobal #research firm #CLSA has retained a #buy call on the #stock with a target price of Rs 290. It is of the view that building the confidence of a turnaround. https://t.co/wYDA5vQvn8',
#   'From ₹550 to ₹120 .\nReally future Tesla 🤦🤦 \n#TataMotors $TSLA #stocks\n#StockMarket #stocks\nHi, check out Tata Motors stock\nhttps://t.co/MaqODNq3Hi https://t.co/vJaMXEy9tJ',
#   "#OPTION:BUY #TATAMOTORS 280 CALL ABOVE 1.5 TGT &amp; SL \nONLY GIVES PAID CLIENTS \n#share\n#stock \n*****( Without RPM and KYC Don't Trade on this call, It's only for paper Trade)****",
#   'TataMotors :  Todays Low made 265.  surpassing our second target of 270. \n\nWhen everyone is running to buy stock - Smart trader should exit and wait for dip. ( 305 to 265 movment.) \nWe could catch 300 to 270 ( almost 10 %) https://t.co/CvG8nrq5V9',
#   "@RNTata2000 @TataMotors @TataMotors_Cars we are holding tata motor shares ice last 10 years.. Sir as a genuine investor we are not rewarded with any dividend or bonus unlike your other companies. It is just a trust and faith on you we are holding this stock. please don't disappoint this year.",
#   "@sidpatankar @Tata_Safari @TataMotors @carandbike @carandbikehindi They should have differentiated the front fascia more.. I'm not so sure planting an almost stock Harrier look on the front end for what's supposed to be a model that offers more, is such a great idea. Was it so difficult?",
#   'Expect #TataMotors stock to reach lifetime high within a few quarters. \n\nThe Suv segment is a big success in the market.',
#   '#TataMotors Latest News | #TataMotorsShare News | #RatanTata Stock | Alert जो जाओ\nCheck: https://t.co/UTMFlKKzPM',
#   "@TataMotors @TataCompanies \nHello sir when you have huge requirements of Nexon then why don't you produce more Instead of giving 8-10 Weeks waiting period...I ma not telling you to produce and Keep the stock atlest based on the booking you can produce more",
#   '@eshwar_rao_l @Rishikesh_ADX @Jitendra_stock @chartmojo You might be knowing Auto industry is cyclic and booming now. Tyre companies like CEAT are unable to meet requirements so working on expansions. I accumulated  TATAMOTORS near 150 for 3X TGT in long term.',
#   '@pandeyji1093 I am not good at predictions 😀. I just try to identify the trend and any specific pattern. So In case of TATAMOTORS, as I said stock is taking support from 5 days EMA.',
#   'Auto stocks in a volatile session; Nifty Auto dips marginally; Eicher, Ashok Leyland, Tata Motors weighs\nhttps://t.co/nSAKPrS2HD\n#NIFTYAUTO #nifty #StockMarket #StocksToWatch #stock #TataMotors #eichermotors #AshokLeyland',
#   'Auto stocks in a volatile session; Nifty Auto dips marginally; Eicher, Ashok Leyland, Tata Motors weighs\nhttps://t.co/rnjla32Vsf\n#NIFTYAUTO #nifty #StockMarket #StocksToWatch #stock #TataMotors #eichermotors #AshokLeyland',
#   '#tatamotors\n\nFirst two targets achieved.\n\nNow next hurdle for the stock is 355 zone. Stock is currently trading around 285 so still a big room for upside.\n\nCharts suggest a good support around 235-250 zone https://t.co/QgBmwakzws',
#   'RIL, Tata Motors, UltraTech Cement in spotlight\n\nRead more at: https://t.co/dNls1I54gU\n\n#capitalmarket #financialmarket #economynews #relianceindustries #tatamotors #ultratech #stockmarkets #stockalert #stockmarketindia #stocknews',
#   'People are crazy chasing #tatamotors stock. It’s hardly producing n selling EVs which is the future!! Why to invest in such stocks. No.... not my cup of tea!!',
#   'Top Stock to watch out on Jan 25, 2021\n\nReliance Industries \nTata Motors \nYes Bank\nUltratech Cement \nGland Pharma\nJSW Steel\nTata Power\n\n#stocktowatch #StockMarket #sharemarket #nifty50 #sensex #stocks #tatamotors #YesBank #RelianceJio #relianceindustry #TATAELXSI #tatasteel'],
#  ' Almost neautral ')
